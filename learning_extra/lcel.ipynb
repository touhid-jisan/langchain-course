# %%
from dotenv import load_dotenv
load_dotenv()

# %% [markdown]
# ### classic example

# %%
from langchain_openrouter import ChatOpenRouter
from langchain import PromptTemplate

template = """ 
Explain the concept to me in one sentence:

"""
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 from langchain_openrouter import ChatOpenRouter
# ----> 2 from langchain import PromptTemplate
#
# ImportError: cannot import name 'PromptTemplate' from 'langchain' (c:\Users\touhidul\Desktop\touhid\personal\Practice\langchain_t\langchain-course\langchain-course\.venv\Lib\site-packages\langchain\__init__.py)
